# %% [markdown]
# # Comparison of OSDT with CART
# Here OSDT is compared to CART using various complexity settings

# %% [markdown]
# ###### Dependencies

# %%
# All dependencies of this notebook

# third-party imports
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier


# local imports
from lib.model import OSDT
from lib.model_selection import train_cross_validate
from lib.data_processing import read_dataset

# %% [markdown]
# # Experiment
# Run an experiment comparing how both OSDT and CART accuracy vary with $\lambda$

# %%
dataset = read_dataset('data/preprocessed/compas-binary.csv')
X = dataset.values[:,:-1]
y = dataset.values[:,-1]

x_lamb = np.arange(0.001, 1.0, 0.005)
y_cart = []
y_osdt = []

for lamb in x_lamb:
    (n, _m) = dataset.shape
    fold_size = round(n / 2) # 50/50 split for training vs testing set
    
    # May want to go into more detail about how we compute equivalent hyperparameters
    hyperparameters = [{
        'max_depth': 5,
        'min_samples_split': math.ceil(lamb * 2 * fold_size), 
        'min_samples_leaf': math.ceil(lamb * fold_size), 
        'max_leaf_nodes': max(2, math.floor(1 / ( 2 * lamb ))), 
        'min_impurity_decrease': lamb
    }]
    _model, cart_accuracy, _hyperparameters = train_cross_validate(
        dataset,
        DecisionTreeClassifier,
        hyperparameters=hyperparameters)
    y_cart.append(cart_accuracy) # 
    
    hyperparameters = [{}]
    _model, osdt_accuracy, _hyperparameters = train_cross_validate(
        dataset,
        OSDT,
        hyperparameters=hyperparameters)
    y_osdt.append(osdt_accuracy)

plt.scatter(x_lamb, y_cart, marker='^', label="CART")
plt.scatter(x_lamb, y_osdt, marker='o', label="OSDT")

plt.title('Test Accuracy vs $\lambda$')
plt.legend()
plt.xlabel(r'$\lambda$')
plt.ylabel('Test Accuracy')

plt.savefig('figures/test_accuracy_vs_lambda.png')
# Out:
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.2013711929321289
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879042.856838
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.14374208450317383
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.13799595832824707
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.21925616264343262
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879043.263985
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.17233014106750488
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.16929888725280762
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.21062994003295898
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879043.771302
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.37373900413513184
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.359605073928833
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.3201780319213867
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879044.566457
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.16545701026916504
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.16460394859313965
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.10173320770263672
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879044.8783538
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.21373367309570312
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.20130681991577148
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.1960146427154541
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879045.3272362
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.24529480934143066
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.24337005615234375
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.20298981666564941
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879045.817674
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.5407428741455078
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.5389440059661865
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.31403493881225586
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879046.898962
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.19442367553710938
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.19257664680480957
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.2991180419921875
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879047.465869
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.15531492233276367
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.15384387969970703
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.17873096466064453
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879047.8377001
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.17420268058776855
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.1727910041809082
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.331010103225708
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879048.410332
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.19981098175048828
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.19617295265197754
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.1664271354675293
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879048.818227
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.1644890308380127
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.16161322593688965
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.15332388877868652
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879049.172236
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.15236806869506836
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.1507730484008789
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.14620327949523926
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879049.526996
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.17463397979736328
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.17007803916931152
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.1282958984375
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879049.860648
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.11219286918640137
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.11080694198608398
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.09411215782165527
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879050.101237
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.1557309627532959
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.15405011177062988
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.1715090274810791
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879050.4628632
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.14401507377624512
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.1411879062652588
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.16118097305297852
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879050.83494
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.1783139705657959
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.1769428253173828
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.1642899513244629
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879051.246517
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.182966947555542
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.180739164352417
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.21566009521484375
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879051.705493
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.16348004341125488
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.162214994430542
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.23409581184387207
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879052.146797
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.12689423561096191
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.1259913444519043
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.10042119026184082
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879052.398582
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.10821294784545898
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.10748004913330078
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.11185503005981445
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879052.643529
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.360260009765625
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.3589918613433838
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.1901860237121582
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879053.2496278
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.2365100383758545
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.23514819145202637
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.1625499725341797
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879053.6969228
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.11735081672668457
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.11649370193481445
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.11347603797912598
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879053.963365
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.1517479419708252
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.150954008102417
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.16000699996948242
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# ...
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.06652712821960449
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879059.06386
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.08050680160522461
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.07965898513793945
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.06332802772521973
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879059.228929
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.08014392852783203
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.07920384407043457
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.08157801628112793
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879059.4148722
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.1690969467163086
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.15732216835021973
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.12074875831604004
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879059.759891
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.08562469482421875
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.08490395545959473
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.06489801406860352
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879059.926681
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.09133744239807129
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.09057116508483887
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.06266403198242188
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879060.103937
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.09638810157775879
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.09500789642333984
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.09485292434692383
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879060.328301
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.11174392700195312
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.11052894592285156
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# nrule: 12
# ndata: 3453
# gr: [0.00346032 0.00509632 0.00622846 0.00631345 0.00878234 0.00509816
#  0.00593233 0.01578993 0.02611275 0.00274281 0.00053302 0.03359428]
# order: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# odr: [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# the order of x's columns:  [11, 8, 7, 4, 3, 2, 6, 5, 1, 0, 9, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.08896207809448242
# lambda:  0.1
# leaves:  [()]
# num_captured:  [3453]
# num_captured_incorrect:  [1604]
# prediction:  [0]
# Objective:  0.5645236026643499
# Accuracy:  0.5354763973356501
# COUNT of the best tree:  0
# time when the best tree is achieved:  1560879060.555586
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.5390851187029531
# nrule: 12
# ndata: 3454
# gr: [0.00543411 0.00267721 0.00356736 0.00678393 0.00761259 0.00919989
#  0.01165459 0.02382521 0.02613283 0.00385476 0.00036193 0.03908285]
# order: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# odr: [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# the order of x's columns:  [11, 8, 7, 6, 5, 4, 3, 0, 9, 2, 1, 10]
# >>> log: False
# >>> support bound: True
# >>> accu_support: True
# >>> accurate support bound: True
# >>> equiv points bound: True
# >>> lookahead bound: True
# prior_metric= curiosity
# COUNT_UNIQLEAVES: 21
# COUNT_LEAFLOOKUPS: 0
# total time:  0.10791206359863281
# lambda:  0.1
# leaves:  [(-1,), (1,)]
# num_captured:  [2381, 1073]
# num_captured_incorrect:  [874, 355]
# prediction:  [0, 1]
# Objective:  0.555819339895773
# Accuracy:  0.644180660104227
# COUNT of the best tree:  1
# time when the best tree is achieved:  0.1065669059753418
# TOTAL COUNT:  11
# best_is_cart False
# [1 1 1 ... 1 1 1]
# Testing Accuracy: 0.6336518969012453
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-b2f7ae6b72cd> in <module>()
#      22         dataset,
#      23         DecisionTreeClassifier,
# ---> 24         hyperparameters=hyperparameters)
#      25     y_cart.append(cart_accuracy) #
#      26
#
# ~/Dropbox/Courses/NSS/repo/lib/model_selection.py in train_cross_validate(dataset, model_class, hyperparameters, retrain)
#      41         model = model_class(**hyperparameter)
#      42         # print(X_train, y_train)
# ---> 43         model.fit(X_train, y_train)
#      44         accuracy = model.score(X_test, y_test)
#      45
#
# ~/Library/Python/3.6/lib/python/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     799             sample_weight=sample_weight,
#     800             check_input=check_input,
# --> 801             X_idx_sorted=X_idx_sorted)
#     802         return self
#     803
#
# ~/Library/Python/3.6/lib/python/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     246         if -1 < max_leaf_nodes < 2:
#     247             raise ValueError(("max_leaf_nodes {0} must be either None "
# --> 248                               "or larger than 1").format(max_leaf_nodes))
#     249
#     250         if sample_weight is not None:
#
# ValueError: max_leaf_nodes 1 must be either None or larger than 1

# %%
# Saved Previous Results
# (Note: these are training accuracies)
x_lamb = np.arange(0.005, 0.05, 0.001)
y_osdt = [0.669031417402635, 0.669031417402635, 0.6622267265093384, 0.6551324743014333,
 0.6551324743014333, 0.6551324743014334, 0.6551324743014334, 0.6551324743014334,
 0.6551324743014334, 0.6551324743014334, 0.6551324743014333, 0.6551324743014333,
 0.6389170406833647, 0.6389170406833647, 0.6389170406833647, 0.6389170406833647,
 0.6389170406833647, 0.6389170406833647, 0.6389170406833647, 0.6389170406833647,
 0.6389170406833647, 0.6389170406833647, 0.6389170406833647, 0.6389170406833647,
 0.6389170406833647, 0.6389170406833647, 0.6389170406833647, 0.6389170406833647,
 0.6389170406833647, 0.6389170406833647, 0.6389170406833647, 0.6389170406833647,
 0.6389170406833647, 0.6389170406833647, 0.6389170406833647, 0.6389170406833647,
 0.6389170406833647, 0.6389170406833647, 0.6389170406833647, 0.6389170406833647,
 0.6389170406833647, 0.6389170406833647, 0.6389170406833647, 0.6389170406833647,
 0.6389170406833647, 0.6389170406833647]
y_cart = [0.6370967741935484, 0.6370967741935484, 0.5, 0.5,
 0.5, 0.5, 0.5, 0.5,
 0.5, 0.5, 0.5, 0.5,
 0.5, 0.5, 0.5, 0.5,
 0.5, 0.5, 0.5, 0.5,
 0.5, 0.5, 0.5, 0.5,
 0.5, 0.5, 0.5, 0.5,
 0.5, 0.5, 0.5, 0.5,
 0.5, 0.5, 0.5, 0.5,
 0.5, 0.5, 0.5, 0.5,
 0.5, 0.5, 0.5, 0.5,
 0.5, 0.5]

plt.scatter(x_lamb, y_cart, marker='^', label="CART")
plt.scatter(x_lamb, y_osdt, marker='o', label="OSDT")

plt.title('Training Accuracy vs $\lambda$')
plt.legend()
plt.xlabel(r'$\lambda$')
plt.ylabel('Training Accuracy')

plt.savefig('figures/training_accuracy_vs_lambda.png')

# %%
# TODO: there appears to be some kind of experiment happening below
# need to refactor this to match the new interface

# %%
x = x_monk1
y = y_monk1
clf = tree.DecisionTreeClassifier(max_depth = 4, min_samples_split = math.ceil(lamb*2*len(y)), 
                                      min_samples_leaf = math.ceil(lamb*len(y)), 
                                      max_leaf_nodes = math.floor(1/(2*lamb)), 
                                      min_impurity_decrease = lamb
                                     )
clf = clf.fit(x,y)
clf.score(x,y)

# %%
x = x_monk1
y = y_monk1
clf = tree.DecisionTreeClassifier(max_depth = 3, min_samples_split = math.ceil(lamb*2*len(y)), 
                                      min_samples_leaf = math.ceil(lamb*len(y)), 
                                      max_leaf_nodes = math.floor(1/(2*lamb)), 
                                      min_impurity_decrease = lamb
                                     )
clf = clf.fit(x,y)
clf.score(x,y)

# %%
lamb = 0.025
x = x_monk2
y = y_monk2
clf = tree.DecisionTreeClassifier(max_depth = 4, min_samples_split = math.ceil(lamb*2*len(y)), 
                                      min_samples_leaf = math.ceil(lamb*len(y)), 
                                      max_leaf_nodes = math.floor(1/(2*lamb)), 
                                      min_impurity_decrease = lamb
                                     )
clf = clf.fit(x,y)
clf.score(x,y)

# %%
lamb = 0.025
x = x_monk2
y = y_monk2
clf = tree.DecisionTreeClassifier(max_depth = 3, min_samples_split = math.ceil(lamb*2*len(y)), 
                                      min_samples_leaf = math.ceil(lamb*len(y)), 
                                      max_leaf_nodes = math.floor(1/(2*lamb)), 
                                      min_impurity_decrease = lamb
                                     )
clf = clf.fit(x,y)
clf.score(x,y)

# %%
x = x_monk3
y = y_monk3
clf = tree.DecisionTreeClassifier(max_depth = 4, min_samples_split = math.ceil(lamb*2*len(y)), 
                                      min_samples_leaf = math.ceil(lamb*len(y)), 
                                      max_leaf_nodes = math.floor(1/(2*lamb)), 
                                      min_impurity_decrease = lamb
                                     )
clf = clf.fit(x,y)
clf.score(x,y)

# %%
x = x_monk3
y = y_monk3
clf = tree.DecisionTreeClassifier(max_depth = 3, min_samples_split = math.ceil(lamb*2*len(y)), 
                                      min_samples_leaf = math.ceil(lamb*len(y)), 
                                      max_leaf_nodes = math.floor(1/(2*lamb)), 
                                      min_impurity_decrease = lamb
                                     )
clf = clf.fit(x,y)
clf.score(x,y)

# %%
lamb = 0.05
x = x_tictactoe
y = y_tictactoe
clf = tree.DecisionTreeClassifier(max_depth = 4, min_samples_split = math.ceil(lamb*2*len(y)), 
                                      min_samples_leaf = math.ceil(lamb*len(y)), 
                                      max_leaf_nodes = math.floor(1/(2*lamb)), 
                                      min_impurity_decrease = lamb
                                     )
clf = clf.fit(x,y)
clf.score(x,y)

# %%
lamb = 0.05
x = x_tictactoe
y = y_tictactoe
clf = tree.DecisionTreeClassifier(max_depth = 3, min_samples_split = math.ceil(lamb*2*len(y)), 
                                      min_samples_leaf = math.ceil(lamb*len(y)), 
                                      max_leaf_nodes = math.floor(1/(2*lamb)), 
                                      min_impurity_decrease = lamb
                                     )
clf = clf.fit(x,y)
clf.score(x,y)

# %%
x = x_balance
y = y_balance
clf = tree.DecisionTreeClassifier(max_depth = 4, min_samples_split = math.ceil(lamb*2*len(y)), 
                                      min_samples_leaf = math.ceil(lamb*len(y)), 
                                      max_leaf_nodes = math.floor(1/(2*lamb)), 
                                      min_impurity_decrease = lamb
                                     )
clf = clf.fit(x,y)
clf.score(x,y)

# %%
x = x_balance
y = y_balance
clf = tree.DecisionTreeClassifier(max_depth = 3, min_samples_split = math.ceil(lamb*2*len(y)), 
                                      min_samples_leaf = math.ceil(lamb*len(y)), 
                                      max_leaf_nodes = math.floor(1/(2*lamb)), 
                                      min_impurity_decrease = lamb
                                     )
clf = clf.fit(x,y)
clf.score(x,y)

# %%
x = x_compas1
y = y_compas1
clf = tree.DecisionTreeClassifier(max_depth = 4, min_samples_split = math.ceil(lamb*2*len(y)), 
                                      min_samples_leaf = math.ceil(lamb*len(y)), 
                                      max_leaf_nodes = math.floor(1/(2*lamb)), 
                                      min_impurity_decrease = lamb
                                     )
clf = clf.fit(x,y)
clf.score(x,y)

# %%
x = x_compas1
y = y_compas1
clf = tree.DecisionTreeClassifier(max_depth = 3, min_samples_split = math.ceil(lamb*2*len(y)), 
                                      min_samples_leaf = math.ceil(lamb*len(y)), 
                                      max_leaf_nodes = math.floor(1/(2*lamb)), 
                                      min_impurity_decrease = lamb
                                     )
clf = clf.fit(x,y)
clf.score(x,y)

# %%
lamb = 0.01
x = x_car
y = y_car
clf = tree.DecisionTreeClassifier(max_depth = 4, min_samples_split = math.ceil(lamb*2*len(y)), 
                                      min_samples_leaf = math.ceil(lamb*len(y)), 
                                      max_leaf_nodes = math.floor(1/(2*lamb)), 
                                      min_impurity_decrease = lamb
                                     )
clf = clf.fit(x,y)
clf.score(x,y)

# %%
lamb = 0.01
x = x_car
y = y_car
clf = tree.DecisionTreeClassifier(max_depth = 3, min_samples_split = math.ceil(lamb*2*len(y)), 
                                      min_samples_leaf = math.ceil(lamb*len(y)), 
                                      max_leaf_nodes = math.floor(1/(2*lamb)), 
                                      min_impurity_decrease = lamb
                                     )
clf = clf.fit(x,y)
clf.score(x,y)

# %%
leaves_c, prediction_c, dic, nrule, ndata, totaltime, time_c, COUNT, C_c, accu = bbound(x_compas1, y_compas1, lamb=0.005, prior_metric="curiosity")

# %%
predict(leaves_c, prediction_c, dic, x_compas1, y_compas1)

# %%
bbound(x_compas1, y_compas1, lamb=0.005, prior_metric="curiosity")

# %%
bbound(x_compas1, y_compas1, lamb=0.0025, prior_metric="curiosity")

# %%
bbound(x_compas1, y_compas1, lamb=0.00225, prior_metric="curiosity")

# %%
bbound(x_compas1, y_compas1, lamb=0.002, prior_metric="curiosity")

# %%
bbound(x_compas1, y_compas1, lamb=0.00175, prior_metric="curiosity")

# %%
bbound(x_compas1, y_compas1, lamb=0.0015, prior_metric="curiosity")

# %%
bbound(x_compas1, y_compas1, lamb=0.00125, prior_metric="curiosity")

# %%
bbound(x_compas1, y_compas1, lamb=0.001, prior_metric="curiosity")

# %%
bbound(x_compas1, y_compas1, lamb=0.0009, prior_metric="curiosity")

# %%
bbound(x_compas1, y_compas1, lamb=0.0008, prior_metric="curiosity")

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=4, MAXDEPTH=3)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=5, MAXDEPTH=3)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=6, MAXDEPTH=3)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=7, MAXDEPTH=3)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=8, MAXDEPTH=3)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=5, MAXDEPTH=4)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=6, MAXDEPTH=4)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=7, MAXDEPTH=4)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=8, MAXDEPTH=4)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=9, MAXDEPTH=4)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=10, MAXDEPTH=4)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=11, MAXDEPTH=4)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=12, MAXDEPTH=4)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=13, MAXDEPTH=4)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=14, MAXDEPTH=4)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=15, MAXDEPTH=4)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=16, MAXDEPTH=4)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=17)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=18)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=19)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=20)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=21)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=22)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=23)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=24)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=25)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=26)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=27)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=28)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=29)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=30)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=31)

# %%
bbound(x_compas1, y_compas1, lamb=0.000000001, prior_metric="curiosity", MAX_NLEAVES=32)

# %%
_,_,_,_,accu_OSDT = bbound(x_balance, y_balance, lamb=0.01, prior_metric="curiosity", MAXDEPTH=4)
accu_OSDT

# %%
_,_,_,_,accu_OSDT = bbound(x_monk1, y_monk1, lamb=0.025, prior_metric="curiosity", MAXDEPTH=4)
accu_OSDT

# %%
_,_,_,_,accu_OSDT = bbound(x_monk1, y_monk1, lamb=0.025, prior_metric="curiosity", MAXDEPTH=3)
accu_OSDT

# %%
_,_,_,_,accu_OSDT = bbound(x_monk2, y_monk2, lamb=0.025, prior_metric="curiosity", MAXDEPTH=4)
accu_OSDT

# %%
_,_,_,_,accu_OSDT = bbound(x_monk2, y_monk2, lamb=0.025, prior_metric="curiosity", MAXDEPTH=3)
accu_OSDT

# %%
_,_,_,_,accu_OSDT = bbound(x_monk3, y_monk3, lamb=0.025, prior_metric="curiosity", MAXDEPTH=4)
accu_OSDT

# %%
_,_,_,_,accu_OSDT = bbound(x_monk3, y_monk3, lamb=0.025, prior_metric="curiosity", MAXDEPTH=3)
accu_OSDT

# %%
_,_,_,_,accu_OSDT = bbound(x_car, y_car, lamb=0.01, prior_metric="curiosity", MAXDEPTH=4)
accu_OSDT

# %%
_,_,_,_,accu_OSDT = bbound(x_car, y_car, lamb=0.01, prior_metric="curiosity", MAXDEPTH=3)
accu_OSDT

# %%
_,_,_,_,accu_OSDT = bbound(x_tictactoe, y_tictactoe, lamb=0.005, prior_metric="curiosity", MAXDEPTH=4)
accu_OSDT

# %%
_,_,_,_,accu_OSDT = bbound(x_tictactoe, y_tictactoe, lamb=0.005, prior_metric="curiosity", MAXDEPTH=4)
accu_OSDT
