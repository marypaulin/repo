# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import matplotlib.patches as mpatches

# %%
fd = './accuracy/600/'

osdt_compas = pd.DataFrame(pd.read_csv(fd+'osdt_compas.txt',delimiter=";"))
cart_compas = pd.DataFrame(pd.read_csv(fd+'cart_compas.txt',delimiter=";"))
binoct_compas = pd.DataFrame(pd.read_csv(fd+'binoct_compas.txt',delimiter=";"))

osdt_monk1 = pd.DataFrame(pd.read_csv(fd+'osdt_monk1.txt',delimiter=";"))
cart_monk1 = pd.DataFrame(pd.read_csv(fd+'cart_monk1.txt',delimiter=";"))
binoct_monk1 = pd.DataFrame(pd.read_csv(fd+'binoct_monk1.txt',delimiter=";"))

osdt_monk2 = pd.DataFrame(pd.read_csv(fd+'osdt_monk2.txt',delimiter=";"))
cart_monk2 = pd.DataFrame(pd.read_csv(fd+'cart_monk2.txt',delimiter=";"))
binoct_monk2 = pd.DataFrame(pd.read_csv(fd+'binoct_monk2.txt',delimiter=";"))

osdt_monk3 = pd.DataFrame(pd.read_csv(fd+'osdt_monk3.txt',delimiter=";"))
cart_monk3 = pd.DataFrame(pd.read_csv(fd+'cart_monk3.txt',delimiter=";"))
binoct_monk3 = pd.DataFrame(pd.read_csv(fd+'binoct_monk3.txt',delimiter=";"))

osdt_car = pd.DataFrame(pd.read_csv(fd+'osdt_car.txt',delimiter=";"))
cart_car = pd.DataFrame(pd.read_csv(fd+'cart_car.txt',delimiter=";"))
binoct_car = pd.DataFrame(pd.read_csv(fd+'binoct_car.txt',delimiter=";"))

osdt_balance = pd.DataFrame(pd.read_csv(fd+'osdt_balance.txt',delimiter=";"))
cart_balance = pd.DataFrame(pd.read_csv(fd+'cart_balance.txt',delimiter=";"))
binoct_balance = pd.DataFrame(pd.read_csv(fd+'binoct_balance.txt',delimiter=";"))

osdt_tictactoe = pd.DataFrame(pd.read_csv(fd+'osdt_tictactoe.txt',delimiter=";"))
cart_tictactoe = pd.DataFrame(pd.read_csv(fd+'cart_tictactoe.txt',delimiter=";"))
binoct_tictactoe = pd.DataFrame(pd.read_csv(fd+'binoct_tictactoe.txt',delimiter=";"))

osdt_fico = pd.DataFrame(pd.read_csv(fd+'osdt_fico.txt',delimiter=";"))
cart_fico = pd.DataFrame(pd.read_csv(fd+'cart_fico.txt',delimiter=";"))
binoct_fico = pd.DataFrame(pd.read_csv(fd+'binoct_fico.txt',delimiter=";"))

# %%
osdt_compas
# Out:
#     fold    lamb  nleaves  trainaccu_CART  testaccu_CART   totaltime  \
# 0      1  0.1000        2        0.641833       0.633087    0.230018
# 1      2  0.1000        1        0.541585       0.528671    0.209667
# 2      3  0.1000        2        0.638002       0.640747    0.215784
# 3      1  0.0500        2        0.641833       0.633087    0.223638
# 4      2  0.0500        2        0.636916       0.642919    0.221628
# 5      3  0.0500        2        0.638002       0.640747    0.229241
# 6      1  0.0250        2        0.641833       0.633087    1.774125
# 7      2  0.0250        2        0.636916       0.642919    1.887224
# 8      3  0.0250        2        0.638002       0.640747    1.724470
# 9      1  0.0100        3        0.654865       0.655667   12.714095
# 10     2  0.0100        3        0.654506       0.651607   14.917821
# 11     3  0.0100        3        0.657763       0.649870    8.896556
# 12     1  0.0050        5        0.669635       0.667825   41.973004
# ...

# %%
fd = './accuracy/3600/'

osdt_compas = pd.DataFrame(pd.read_csv(fd+'osdt_compas.txt',delimiter=";"))
cart_compas = pd.DataFrame(pd.read_csv(fd+'cart_compas.txt',delimiter=";"))
binoct_compas = pd.DataFrame(pd.read_csv(fd+'binoct_compas.txt',delimiter=";"))

# %%
osdt_compas
# Out:
#     fold     lamb  nleaves  trainaccu_CART  testaccu_CART    totaltime  \
# 0      1  0.10000        2        0.641833       0.633087     0.231216
# 1      2  0.10000        1        0.541585       0.528671     0.221337
# 2      3  0.10000        2        0.638002       0.640747     0.221855
# 3      1  0.05000        2        0.641833       0.633087     0.224571
# 4      2  0.05000        2        0.636916       0.642919     0.228145
# 5      3  0.05000        2        0.638002       0.640747     0.229665
# 6      1  0.02500        2        0.641833       0.633087     1.855516
# 7      2  0.02500        2        0.636916       0.642919     1.860601
# 8      3  0.02500        2        0.638002       0.640747     1.741969
# 9      1  0.01000        3        0.654865       0.655667    12.639087
# 10     2  0.01000        3        0.654506       0.651607    14.772262
# 11     3  0.01000        3        0.657763       0.649870     9.014168
# ...

# %%
def draw_accuracy(osdt_data, cart_data, binoct_data, fd, dataname):
    plt.figure(num=None, figsize=(8, 6), facecolor='w', edgecolor='k')

    ax = plt.axes()

    ax.plot(osdt_data['nleaves'][osdt_data['fold'] == fd], osdt_data['trainaccu_CART'][osdt_data['fold'] == fd], '>',
            markersize=12, color = 'blue', label='OSDT-Train')
    ax.plot(osdt_data['nleaves'][osdt_data['fold'] == fd], osdt_data['testaccu_CART'][osdt_data['fold'] == fd], '>',
            markersize=12, color = 'orange', label='OSDT-Test')

    ax.plot(cart_data['nleaves'][cart_data['fold'] == fd], cart_data['trainaccu_CART'][cart_data['fold'] == fd], '+',
            markersize=12, color = 'blue', label='CART-Train')
    ax.plot(cart_data['nleaves'][cart_data['fold'] == fd], cart_data['testaccu_CART'][cart_data['fold'] == fd], '+',
            markersize=12, color = 'orange', label='CART-Test')

    ax.plot(binoct_data['nleaves'][binoct_data['fold'] == fd], binoct_data['trainaccu'][binoct_data['fold'] == fd], 'x',
            markersize=12, color='blue', label='BinOCT-Train')
    ax.plot(binoct_data['nleaves'][binoct_data['fold'] == fd], binoct_data['testaccu'][binoct_data['fold'] == fd], 'x',
            markersize=12, color='orange', label='BinOCT-Test')

    ax.set_xlabel('Number of Leaves')
    ax.set_ylabel('Accuracy')
    ax.set_title('Classification Accuracy of ' + str(dataname) + ' Dataset ' + str(fd))

    #blue_line = mlines.Line2D([], [], color='black', marker='x',
    #                          markersize=12, label='Blue stars')
    #blue_patch = mpatches.Patch(color='blue', label='The training accuracy')
    #orange_patch = mpatches.Patch(color='orange', label='The testing accuracy')
    #ax.legend(handles=[blue_patch, orange_patch, blue_line], loc=4)

    ax.legend(loc='best')

    plt.savefig("./accuracy/" + str(dataname) + str(fd) + ".pdf", bbox_inches='tight')

    plt.show()

# %%
# ONLY ONE FOLD
def draw_accuracy_train(osdt_data, cart_data, binoct_data, dataname):
    plt.figure(num=None, figsize=(8, 6), facecolor='w', edgecolor='k')

    ax = plt.axes()

    ax.plot(osdt_data['nleaves'][osdt_data['nleaves'] > 1], osdt_data['trainaccu_CART'][osdt_data['nleaves'] > 1], '>',
            markersize=12, color = 'blue', label='OSDT-Train')
    #ax.plot(osdt_data['nleaves'][osdt_data['fold'] == fd], osdt_data['testaccu_CART'][osdt_data['fold'] == fd], '>',
            #markersize=12, color = 'orange', label='OSDT-Test')

    ax.plot(cart_data['nleaves'][cart_data['nleaves'] > 1], cart_data['trainaccu_CART'][cart_data['nleaves'] > 1], '+',
            markersize=12, color = 'blue', label='CART-Train')
    #ax.plot(cart_data['nleaves'][cart_data['fold'] == fd], cart_data['testaccu_CART'][cart_data['fold'] == fd], '+',
            #markersize=12, color = 'orange', label='CART-Test')

    ax.plot(binoct_data['nleaves'][binoct_data['nleaves'] > 1], binoct_data['trainaccu'][binoct_data['nleaves'] > 1], 'x',
            markersize=12, color='blue', label='BinOCT-Train')
    #ax.plot(binoct_data['nleaves'][binoct_data['fold'] == fd], binoct_data['testaccu'][binoct_data['fold'] == fd], 'x',
            #markersize=12, color='orange', label='BinOCT-Test')
        
    ax.set_xlim(0, max(osdt_data['nleaves'])+2)
    

    ax.set_xlabel('Number of Leaves')
    ax.set_ylabel('Accuracy')
    ax.set_title('Classification Accuracy of ' + str(dataname) + ' Dataset ')

    #blue_line = mlines.Line2D([], [], color='black', marker='x',
    #                          markersize=12, label='Blue stars')
    #blue_patch = mpatches.Patch(color='blue', label='The training accuracy')
    #orange_patch = mpatches.Patch(color='orange', label='The testing accuracy')
    #ax.legend(handles=[blue_patch, orange_patch, blue_line], loc=4)

    ax.legend(loc='best')

    plt.savefig("./accuracy/" + str(dataname) + ".pdf", bbox_inches='tight')

    plt.show()

# %%
fd = './accuracy/1800warm/'

osdt_compas = pd.DataFrame(pd.read_csv(fd+'osdt_compas.txt',delimiter=";"))
cart_compas = pd.DataFrame(pd.read_csv(fd+'cart_compas.txt',delimiter=";"))
binoct_compas = pd.DataFrame(pd.read_csv(fd+'binoct_compas.txt',delimiter=";"))

osdt_monk1 = pd.DataFrame(pd.read_csv(fd+'osdt_monk1.txt',delimiter=";"))
cart_monk1 = pd.DataFrame(pd.read_csv(fd+'cart_monk1.txt',delimiter=";"))
binoct_monk1 = pd.DataFrame(pd.read_csv(fd+'binoct_monk1.txt',delimiter=";"))

osdt_monk2 = pd.DataFrame(pd.read_csv(fd+'osdt_monk2.txt',delimiter=";"))
cart_monk2 = pd.DataFrame(pd.read_csv(fd+'cart_monk2.txt',delimiter=";"))
binoct_monk2 = pd.DataFrame(pd.read_csv(fd+'binoct_monk2.txt',delimiter=";"))

osdt_monk3 = pd.DataFrame(pd.read_csv(fd+'osdt_monk3.txt',delimiter=";"))
cart_monk3 = pd.DataFrame(pd.read_csv(fd+'cart_monk3.txt',delimiter=";"))
binoct_monk3 = pd.DataFrame(pd.read_csv(fd+'binoct_monk3.txt',delimiter=";"))

osdt_car = pd.DataFrame(pd.read_csv(fd+'osdt_car.txt',delimiter=";"))
cart_car = pd.DataFrame(pd.read_csv(fd+'cart_car.txt',delimiter=";"))
binoct_car = pd.DataFrame(pd.read_csv(fd+'binoct_car.txt',delimiter=";"))

osdt_tictactoe = pd.DataFrame(pd.read_csv(fd+'osdt_tictactoe.txt',delimiter=";"))
cart_tictactoe = pd.DataFrame(pd.read_csv(fd+'cart_tictactoe.txt',delimiter=";"))
binoct_tictactoe = pd.DataFrame(pd.read_csv(fd+'binoct_tictactoe.txt',delimiter=";"))

osdt_fico = pd.DataFrame(pd.read_csv(fd+'osdt_fico.txt',delimiter=";"))
cart_fico = pd.DataFrame(pd.read_csv(fd+'cart_fico.txt',delimiter=";"))
binoct_fico = pd.DataFrame(pd.read_csv(fd+'binoct_fico.txt',delimiter=";"))

# %%
draw_accuracy_train(osdt_compas, cart_compas, binoct_compas,'compas')
draw_accuracy_train(osdt_car, cart_car, binoct_car,'car')
draw_accuracy_train(osdt_fico, cart_fico, binoct_fico,'fico')
draw_accuracy_train(osdt_tictactoe, cart_tictactoe, binoct_tictactoe,'tictactoe')
draw_accuracy_train(osdt_monk1, cart_monk1, binoct_monk1,'monk1')
draw_accuracy_train(osdt_monk2, cart_monk2, binoct_monk2,'monk2')
draw_accuracy_train(osdt_monk3, cart_monk3, binoct_monk3,'monk3')

# %%
for fd in [1,2,3]:
    draw_accuracy(osdt_compas, cart_compas, binoct_compas, fd, 'compas')

# %%
for fd in [1,2,3]:
    draw_accuracy(osdt_car, cart_car, binoct_car, fd, 'car')

# %%
for fd in [1,2,3]:
    draw_accuracy(osdt_monk1, cart_monk1, binoct_monk1, fd, 'monk1')

# %%
for fd in [1,2,3]:
    draw_accuracy(osdt_monk2, cart_monk2, binoct_monk2, fd, 'monk2')

# %%
for fd in [1,2,3]:
    draw_accuracy(osdt_monk3, cart_monk3, binoct_monk3, fd, 'monk3')

# %%
for fd in [1,2,3]:
    draw_accuracy(osdt_balance, cart_balance, binoct_balance, fd, 'balance')

# %%
for fd in [1,2,3]:
    draw_accuracy(osdt_fico, cart_fico, binoct_fico, fd, 'fico')

# %%
for fd in [1,2,3]:
    draw_accuracy(osdt_tictactoe, cart_tictactoe, binoct_tictactoe, fd, 'tictactoe')
